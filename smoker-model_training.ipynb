# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/smoking.csv')
df
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 2          2      M   55         170          60       80.0             0.8
# 3          3      M   40         165          70       88.0             1.5
# 4          4      F   40         155          60       86.0             1.0
# ...      ...    ...  ...         ...         ...        ...             ...
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
# 55690  55684      M   60         165          60       78.0             0.8
# 55691  55691      M   55         160          65       85.0             0.9
#
# ...

# %%
X = df.loc[:, df.columns != 'smoking']
X
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 2          2      M   55         170          60       80.0             0.8
# 3          3      M   40         165          70       88.0             1.5
# 4          4      F   40         155          60       86.0             1.0
# ...      ...    ...  ...         ...         ...        ...             ...
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
# 55690  55684      M   60         165          60       78.0             0.8
# 55691  55691      M   55         160          65       85.0             0.9
#
# ...

# %%
y = df['smoking']
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 55687    0
# 55688    0
# 55689    0
# 55690    0
# 55691    1
# Name: smoking, Length: 55692, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (44553, 26) (44553,)
# Test set: (11139, 26) (11139,)

# %%
from sklearn.preprocessing import LabelEncoder
l1 = LabelEncoder()
l1.fit(X_train[['gender']])
X_train['gender']=l1.transform(X_train[['gender']])
X_test['gender']=l1.transform(X_test[['gender']])

l1.fit(X_train[['oral']])
X_train['oral']=l1.transform(X_train[['oral']])
X_test['oral']=l1.transform(X_test[['oral']])

l1.fit(X_train[['tartar']])
X_train['tartar']=l1.transform(X_train[['tartar']])
X_test['tartar']=l1.transform(X_test[['tartar']])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# ...

# %%
X_train
# Out:
#           ID  gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 36237  45285       0   55         150          50       80.0             0.9
# 14939  18637       1   30         180          65       68.2             1.2
# 31835  39766       1   40         170          80       94.0             0.8
# 49085  22791       0   60         155          50       67.5             0.8
# 30684  38337       1   25         180          70       78.0             1.0
# ...      ...     ...  ...         ...         ...        ...             ...
# 55169  53050       0   60         145          50       75.0             0.9
# 49861  26616       0   60         150          50       73.0             0.8
# 27063  33764       1   50         170          80       84.0             1.5
# 8366   10503       1   45         160          50       68.0             1.0
# 17530  21868       0   45         150          55       84.8             1.2
#
# ...

# %%
X_test
# Out:
#           ID  gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 17253  21508       1   40         170          70       86.7             0.8
# 52470  39708       1   40         175          60       78.0             1.2
# 52334  39002       0   60         150          55       74.0             0.9
# 16234  20239       1   35         180         105      104.0             1.2
# 21046  26285       1   60         160          65       77.0             0.7
# ...      ...     ...  ...         ...         ...        ...             ...
# 25346  31673       0   60         160          65       85.0             1.0
# 6079    7649       1   40         170          65       81.0             0.9
# 48498  19912       0   45         155          65       84.0             0.6
# 43680  54596       1   25         175          80       90.0             1.0
# 10930  13675       1   40         170          70       79.0             0.4
#
# ...

# %%
# Application of SVMs ( Normalized data with feature preprocessing using minmax scaling )
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svm_minmax = SVC(C=10).fit(X_train_scaled, y_train)
print('Smoking dataset (normalized with MinMax scaling)')
print('RBF-kernel SVC (with MinMax scaling) training set accuracy: {:.2f}'
     .format(svm_minmax.score(X_train_scaled, y_train)))
print('RBF-kernel SVC (with MinMax scaling) test set accuracy: {:.2f}'
     .format(svm_minmax.score(X_test_scaled, y_test)))
# Out:
# Smoking dataset (normalized with MinMax scaling)
# RBF-kernel SVC (with MinMax scaling) training set accuracy: 0.76
# RBF-kernel SVC (with MinMax scaling) test set accuracy: 0.76

# %%
#svm rbf c=1
# Accuracy of Support Vector Machine classifier
from sklearn.svm import SVC

svm1 = SVC(kernel='rbf', C=1).fit(X_train, y_train)
svm1.score(X_test, y_test)
# Out:
# 0.6299488284406141

# %%
#svm linear c=1

from sklearn.svm import LinearSVC
svm2 = LinearSVC(C=1).fit(X_train, y_train)
svm2.score(X_test, y_test)
# Out:
# 0.7077834635065985

# %%
#svm linear c=2.5

svm3 = LinearSVC(C=2.5).fit(X_train, y_train)
svm3.score(X_test, y_test)
# Out:
# 0.7322919472124967

# %%
#svm linear c=i
"""
i=2
while i<3:

    svm9= LinearSVC(C=i).fit(X_train, y_train)

    print(i," : ",svm9.score(X_test, y_test))
    i=i+0.1
    """
# Out:
# '\ni=2\nwhile i<3:\n\n    svm9= LinearSVC(C=i).fit(X_train, y_train)\n    \n    print(i," : ",svm9.score(X_test, y_test))\n    i=i+0.1\n    '

# %%
from sklearn.datasets import make_classification
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
cmap_bold = ListedColormap(['#FF0000','#000000'])


#dataset for classification (binary)
plt.figure()
plt.title('Sample binary classification problem with two informative features')
X_C2, y_C2 = make_classification(n_samples = 100, n_features=2,
                                n_redundant=0, n_informative=2,
                                n_clusters_per_class=1, flip_y = 0.1,
                                class_sep = 0.5, random_state=0)
plt.scatter(X_C2[:, 0], X_C2[:, 1], c=y_C2,
           marker= 'o', s=50, cmap=cmap_bold)
plt.legend("Smoker")
plt.show()

# %%
"""
from adspy_shared_utilities import plot_class_regions_for_classifier

fig, subaxes = plt.subplots(3, 1, figsize=(4, 11))

for this_gamma, subplot in zip([0.01, 1.0, 10.0], subaxes):
    clf = SVC(kernel = 'rbf', gamma=this_gamma).fit(X_train, y_train)
    title = 'Support Vector Classifier: \nRBF kernel, gamma = {:.2f}'.format(this_gamma)
    plot_class_regions_for_classifier_subplot(clf, X_train, y_train,
                                             None, None, title, subplot)
    plt.tight_layout()
"""
# Out:
# "\nfrom adspy_shared_utilities import plot_class_regions_for_classifier\n\nfig, subaxes = plt.subplots(3, 1, figsize=(4, 11))\n\nfor this_gamma, subplot in zip([0.01, 1.0, 10.0], subaxes):\n    clf = SVC(kernel = 'rbf', gamma=this_gamma).fit(X_train, y_train)\n    title = 'Support Vector Classifier: \nRBF kernel, gamma = {:.2f}'.format(this_gamma)\n    plot_class_regions_for_classifier_subplot(clf, X_train, y_train,\n                                             None, None, title, subplot)\n    plt.tight_layout()\n"

# %%
# Naive Bayes is a classification algorithm for binary and multiclass classification problems.
#  It is called Naive Bayes or idiot Bayes because the calculations of the probabilities for each class are simplified
# to make their calculations tractable.
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
y_pred_gnb = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred_gnb).sum()))
print('Accuracy of Naive Bayes classifier on train set:' , gnb.score(X_train, y_train))
print('Accuracy of Naive Bayes classifier on test set:' , gnb.score(X_test, y_test))
# Out:
# Number of mislabeled points out of a total 11139 points : 3225
# Accuracy of Naive Bayes classifier on train set: 0.7013220209637959
# Accuracy of Naive Bayes classifier on test set: 0.7104767034742796

# %%
#The k-nearest neighbors (KNN) algorithm is a data classification method for estimating the likelihood that a data point
#  will become a member of one group or another based on what group the data points nearest to it belong to
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
print('Accuracy of K Neighbors Classifier on train set:' , classifier.score(X_train, y_train))
print('Accuracy of K Neighbors Classifier on test set:' , classifier.score(X_test, y_test))
# Out:
# Accuracy of K Neighbors Classifier on train set: 0.7665252620474491
# Accuracy of K Neighbors Classifier on test set: 0.6494299308735075

# %%
from sklearn.metrics import confusion_matrix

kneigh_predicted = classifier.predict(X_test)
confusion = confusion_matrix(y_test, kneigh_predicted)

print('Support vector machine classifier (linear kernel, C=1)\n', confusion)
# Out:
# Support vector machine classifier (linear kernel, C=1)
#  [[5491 1526]
#  [2379 1743]]

# %%
###TN   FP
###FN   TP

# %%
from sklearn.metrics import confusion_matrix

svm_predicted = svm2.predict(X_test)
confusion = confusion_matrix(y_test, svm_predicted)

print('Support vector machine classifier (linear kernel, C=1)\n', confusion)
# Out:
# Support vector machine classifier (linear kernel, C=1)
#  [[5991 1026]
#  [2229 1893]]

# %%
svm_predicted = svm3.predict(X_test)
confusion = confusion_matrix(y_test, svm_predicted)
print('Support vector machine classifier (linear kernel, C=2.5)\n', confusion)
# Out:
# Support vector machine classifier (linear kernel, C=2.5)
#  [[5754 1263]
#  [1719 2403]]

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
tree_predicted = dt.predict(X_test)
confusion = confusion_matrix(y_test, tree_predicted)

print('Decision tree classifier (max_depth = 2)\n', confusion)
# Out:
# Decision tree classifier (max_depth = 2)
#  [[5749 1268]
#  [1731 2391]]

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=2000).fit(X_train, y_train)
lr_predicted = lr.predict(X_test)
confusion = confusion_matrix(y_test, lr_predicted)

print('Logistic regression classifier max_iter=2000 \n', confusion)
# Out:
# Logistic regression classifier max_iter=2000
#  [[5810 1207]
#  [1938 2184]]
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report
print('SVM\n',
      classification_report(y_test, svm_predicted, target_names = ['not 1', '1']))
print('Logistic regression\n',
      classification_report(y_test, lr_predicted, target_names = ['not 1', '1']))
# Out:
# SVM
#                precision    recall  f1-score   support
#
#        not 1       0.77      0.82      0.79      7017
#            1       0.66      0.58      0.62      4122
#
#     accuracy                           0.73     11139
#    macro avg       0.71      0.70      0.71     11139
# weighted avg       0.73      0.73      0.73     11139
#
# Logistic regression
#                precision    recall  f1-score   support
#
#        not 1       0.75      0.83      0.79      7017
#            1       0.64      0.53      0.58      4122
#
#     accuracy                           0.72     11139
#    macro avg       0.70      0.68      0.68     11139
# weighted avg       0.71      0.72      0.71     11139

# %%
print('Decision tree\n',
      classification_report(y_test, tree_predicted, target_names = ['not 1', '1']))
# Out:
# Decision tree
#                precision    recall  f1-score   support
#
#        not 1       0.77      0.82      0.79      7017
#            1       0.65      0.58      0.61      4122
#
#     accuracy                           0.73     11139
#    macro avg       0.71      0.70      0.70     11139
# weighted avg       0.73      0.73      0.73     11139

# %%
print('K Neighbors\n',
      classification_report(y_test, kneigh_predicted, target_names = ['not 1', '1']))
print('Naive Bayes\n',
      classification_report(y_test, y_pred_gnb, target_names = ['not 1', '1']))
# Out:
# K Neighbors
#                precision    recall  f1-score   support
#
#        not 1       0.70      0.78      0.74      7017
#            1       0.53      0.42      0.47      4122
#
#     accuracy                           0.65     11139
#    macro avg       0.62      0.60      0.60     11139
# weighted avg       0.64      0.65      0.64     11139
#
# Naive Bayes
#                precision    recall  f1-score   support
#
#        not 1       0.80      0.73      0.76      7017
#            1       0.59      0.68      0.64      4122
#
#     accuracy                           0.71     11139
#    macro avg       0.70      0.70      0.70     11139
# weighted avg       0.72      0.71      0.71     11139

# %%
#Precision-recall curves
from sklearn.metrics import precision_recall_curve

y_score_lr = lr.fit(X_train, y_train).decision_function(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_score_lr)
closest_zero = np.argmin(np.abs(thresholds))
closest_zero_p = precision[closest_zero]
closest_zero_r = recall[closest_zero]

plt.figure()
plt.xlim([0.0, 1.01])
plt.ylim([0.0, 1.01])
plt.plot(precision, recall, label='Precision-Recall Curve')
plt.plot(closest_zero_p, closest_zero_r, 'o', markersize = 12, fillstyle = 'none', c='r', mew=3)
plt.xlabel('Precision', fontsize=16)
plt.ylabel('Recall', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# ROC curves, Area-Under-Curve (AUC)
from sklearn.metrics import roc_curve, auc

y_score_lr = lr.fit(X_train, y_train).decision_function(X_test)
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_score_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr_lr, tpr_lr, lw=3, label='LogRegr ROC curve (area = {:0.2f})'.format(roc_auc_lr))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve (1-of-10 digits classifier)', fontsize=16)
plt.legend(loc='lower right', fontsize=13)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from matplotlib import cm
plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
for g in [0.01, 0.1, 0.20, 1]:
    svm = SVC(gamma=g).fit(X_train, y_train)
    y_score_svm = svm.decision_function(X_test)
    fpr_svm, tpr_svm, _ = roc_curve(y_test, y_score_svm)
    roc_auc_svm = auc(fpr_svm, tpr_svm)
    accuracy_svm = svm.score(X_test, y_test)
    print("gamma = {:.2f}  accuracy = {:.2f}   AUC = {:.2f}".format(g, accuracy_svm,
                                                                    roc_auc_svm))
    plt.plot(fpr_svm, tpr_svm, lw=3, alpha=0.7,
             label='SVM (gamma = {:0.2f}, area = {:0.2f})'.format(g, roc_auc_svm))

plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate (Recall)', fontsize=16)
plt.plot([0, 1], [0, 1], color='k', lw=0.5, linestyle='--')
plt.legend(loc="lower right", fontsize=11)
plt.title('ROC curve: (1-of-10 digits classifier)', fontsize=16)

plt.show()
# Out:
# gamma = 0.01  accuracy = 0.63   AUC = 0.61
# gamma = 0.10  accuracy = 0.63   AUC = 0.50
# gamma = 0.20  accuracy = 0.63   AUC = 0.50
# gamma = 1.00  accuracy = 0.63   AUC = 0.50

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

bdt = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=2), algorithm="SAMME", n_estimators=200
)

bdt.fit(X_train, y_train)

bdt_predicted = bdt.predict(X_test)
confusion = confusion_matrix(y_test, bdt_predicted)

print('AdaBoosted decision tree classifier\n', confusion)
print('Accuracy of AdaBoosted decision tree Classifier on train set:' , bdt.score(X_train, y_train))
print('Accuracy of AdaBoosted decision tree Classifier on test set:' , bdt.score(X_test, y_test))
print('AdaBoosted\n',
      classification_report(y_test, bdt_predicted, target_names = ['not 1', '1']))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# AdaBoosted decision tree classifier
#  [[5626 1391]
#  [1261 2861]]
# Accuracy of AdaBoosted decision tree Classifier on train set: 0.7629340336228762
# Accuracy of AdaBoosted decision tree Classifier on test set: 0.761917586856989
# AdaBoosted
#                precision    recall  f1-score   support
#
#        not 1       0.82      0.80      0.81      7017
#            1       0.67      0.69      0.68      4122
#
#     accuracy                           0.76     11139
#    macro avg       0.74      0.75      0.75     11139
# weighted avg       0.76      0.76      0.76     11139

# %%
from sklearn.svm import LinearSVC
from sklearn.ensemble import BaggingClassifier

baggingclf = BaggingClassifier(estimator=LinearSVC(), n_estimators=10, random_state=0)

baggingclf.fit(X_train, y_train)

baggingclf_predicted = baggingclf.predict(X_test)
confusion = confusion_matrix(y_test, baggingclf_predicted)

print('Bagging Classifier\n', confusion)
print('Accuracy of Bagging Classifier on train set:' , baggingclf.score(X_train, y_train))
print('Accuracy of Bagging Classifier on test set:' , baggingclf.score(X_test, y_test))
print('Bagging\n',
      classification_report(y_test, baggingclf_predicted, target_names = ['not 1', '1']))
# Out:
# Bagging Classifier
#  [[5869 1148]
#  [1959 2163]]
# Accuracy of Bagging Classifier on train set: 0.7204677575023006
# Accuracy of Bagging Classifier on test set: 0.7210701140138253
# Bagging
#                precision    recall  f1-score   support
#
#        not 1       0.75      0.84      0.79      7017
#            1       0.65      0.52      0.58      4122
#
#     accuracy                           0.72     11139
#    macro avg       0.70      0.68      0.69     11139
# weighted avg       0.71      0.72      0.71     11139

# %%
from sklearn.svm import LinearSVC
from sklearn.ensemble import BaggingClassifier

baggingclf = BaggingClassifier(estimator= AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=2), algorithm="SAMME", n_estimators=100
), n_estimators=5, random_state=0)

baggingclf.fit(X_train, y_train)

baggingclf_predicted = baggingclf.predict(X_test)
confusion = confusion_matrix(y_test, baggingclf_predicted)

print('Bagging Classifier\n', confusion)
print('Accuracy of Bagging Classifier on train set:' , baggingclf.score(X_train, y_train))
print('Accuracy of Bagging Classifier on test set:' , baggingclf.score(X_test, y_test))
print('Bagging\n',
      classification_report(y_test, baggingclf_predicted, target_names = ['not 1', '1']))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:610: RuntimeWarning: divide by zero encountered in log
#   np.log(sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:610: RuntimeWarning: divide by zero encountered in log
#   np.log(sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:610: RuntimeWarning: divide by zero encountered in log
#   np.log(sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:610: RuntimeWarning: divide by zero encountered in log
#   np.log(sample_weight)
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:610: RuntimeWarning: divide by zero encountered in log
# ...

# %%
from sklearn.svm import SVC
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
param_grid= {'kernel': ('linear', 'rbf'), 'C': [1, 10, 100]}
base_estimator = SVC(gamma='scale')
sh = HalvingGridSearchCV(base_estimator, param_grid, cv=5, factor=2, min_resources=20)

sh.fit(X_train, y_train)

sh_predicted = sh.predict(X_test)
confusion = confusion_matrix(y_test, sh_predicted)

print('HalvingGridSearchCV Classifier\n', confusion)
print('Accuracy of HalvingGridSearchCV Classifier on train set:' , sh.score(X_train, y_train))
print('Accuracy of HalvingGridSearchCV Classifier on test set:' , sh.score(X_test, y_test))
print('HalvingGridSearchCV\n',
      classification_report(y_test, sh_predicted, target_names = ['not 1', '1']))
# Out:
# HalvingGridSearchCV Classifier
#  [[7004   13]
#  [4066   56]]
# Accuracy of HalvingGridSearchCV Classifier on train set: 0.6363881220119857
# Accuracy of HalvingGridSearchCV Classifier on test set: 0.633809139060957
# HalvingGridSearchCV
#                precision    recall  f1-score   support
#
#        not 1       0.63      1.00      0.77      7017
#            1       0.81      0.01      0.03      4122
#
#     accuracy                           0.63     11139
#    macro avg       0.72      0.51      0.40     11139
# weighted avg       0.70      0.63      0.50     11139

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

bagging = BaggingClassifier(KNeighborsClassifier(), max_samples=0.5, max_features=0.5)

bagging.fit(X_train, y_train)

bagging_predicted = bagging.predict(X_test)
confusion = confusion_matrix(y_test, bagging_predicted)

print('Bagging Kneighbors Classifier\n', confusion)
print('Accuracy of Bagging Kneighbors Classifier on train set:' , bagging.score(X_train, y_train))
print('Accuracy of Bagging Kneighbors Classifier on test set:' , bagging.score(X_test, y_test))
print('Bagging Kneighbors\n',
      classification_report(y_test, bagging_predicted, target_names = ['not 1', '1']))
# Out:
# Bagging Kneighbors Classifier
#  [[6017 1000]
#  [2035 2087]]
# Accuracy of Bagging Kneighbors Classifier on train set: 0.8164433371490135
# Accuracy of Bagging Kneighbors Classifier on test set: 0.72753388993626
# Bagging Kneighbors
#                precision    recall  f1-score   support
#
#        not 1       0.75      0.86      0.80      7017
#            1       0.68      0.51      0.58      4122
#
#     accuracy                           0.73     11139
#    macro avg       0.71      0.68      0.69     11139
# weighted avg       0.72      0.73      0.72     11139

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=50)

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('RandomForest Classifier\n', confusion)
print('Accuracy of RandomForest Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of RandomForest Classifier on test set:' , clf.score(X_test, y_test))
print('RandomForest\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# RandomForest Classifier
#  [[6076  941]
#  [ 953 3169]]
# Accuracy of RandomForest Classifier on train set: 0.9998428837564249
# Accuracy of RandomForest Classifier on test set: 0.829966783373732
# RandomForest
#                precision    recall  f1-score   support
#
#        not 1       0.86      0.87      0.87      7017
#            1       0.77      0.77      0.77      4122
#
#     accuracy                           0.83     11139
#    macro avg       0.82      0.82      0.82     11139
# weighted avg       0.83      0.83      0.83     11139

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=2)

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('DecisionTree Classifier\n', confusion)
print('Accuracy of DecisionTree Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of DecisionTree Classifier on test set:' , clf.score(X_test, y_test))
print('DecisionTree\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# DecisionTree Classifier
#  [[5749 1268]
#  [1731 2391]]
# Accuracy of DecisionTree Classifier on train set: 0.7248221219670954
# Accuracy of DecisionTree Classifier on test set: 0.7307657778974773
# DecisionTree
#                precision    recall  f1-score   support
#
#        not 1       0.77      0.82      0.79      7017
#            1       0.65      0.58      0.61      4122
#
#     accuracy                           0.73     11139
#    macro avg       0.71      0.70      0.70     11139
# weighted avg       0.73      0.73      0.73     11139

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators=10, max_depth=None, min_samples_split=2, random_state=0)

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('ExtraTrees Classifier\n', confusion)
print('Accuracy of ExtraTrees Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of ExtraTrees Classifier on test set:' , clf.score(X_test, y_test))
print('ExtraTrees\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# ExtraTrees Classifier
#  [[6140  877]
#  [1257 2865]]
# Accuracy of ExtraTrees Classifier on train set: 1.0
# Accuracy of ExtraTrees Classifier on test set: 0.8084208636322829
# ExtraTrees
#                precision    recall  f1-score   support
#
#        not 1       0.83      0.88      0.85      7017
#            1       0.77      0.70      0.73      4122
#
#     accuracy                           0.81     11139
#    macro avg       0.80      0.79      0.79     11139
# weighted avg       0.81      0.81      0.81     11139

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('GradientBoosting Classifier\n', confusion)
print('Accuracy of GradientBoosting Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of GradientBoosting Classifier on test set:' , clf.score(X_test, y_test))
print('GradientBoosting\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# GradientBoosting Classifier
#  [[5578 1439]
#  [1235 2887]]
# Accuracy of GradientBoosting Classifier on train set: 0.7665477072251027
# Accuracy of GradientBoosting Classifier on test set: 0.7599425442140229
# GradientBoosting
#                precision    recall  f1-score   support
#
#        not 1       0.82      0.79      0.81      7017
#            1       0.67      0.70      0.68      4122
#
#     accuracy                           0.76     11139
#    macro avg       0.74      0.75      0.75     11139
# weighted avg       0.76      0.76      0.76     11139

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

clf = HistGradientBoostingClassifier(max_iter=100)

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('HistGradientBoosting Classifier\n', confusion)
print('Accuracy of HistGradientBoosting Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of HistGradientBoosting Classifier on test set:' , clf.score(X_test, y_test))
print('HistGradientBoosting\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# HistGradientBoosting Classifier
#  [[5672 1345]
#  [1100 3022]]
# Accuracy of HistGradientBoosting Classifier on train set: 0.8059389940071375
# Accuracy of HistGradientBoosting Classifier on test set: 0.7805009426339887
# HistGradientBoosting
#                precision    recall  f1-score   support
#
#        not 1       0.84      0.81      0.82      7017
#            1       0.69      0.73      0.71      4122
#
#     accuracy                           0.78     11139
#    macro avg       0.76      0.77      0.77     11139
# weighted avg       0.78      0.78      0.78     11139

# %%
from xgboost import XGBClassifier

clf = XGBClassifier()

clf.fit(X_train, y_train)

clf_predicted = clf.predict(X_test)
confusion = confusion_matrix(y_test, clf_predicted)

print('XGB Classifier\n', confusion)
print('Accuracy of XGB Classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of XGB Classifier on test set:' , clf.score(X_test, y_test))
print('XGB\n',
      classification_report(y_test, clf_predicted, target_names = ['not 1', '1']))
# Out:
# XGB Classifier
#  [[5737 1280]
#  [1148 2974]]
# Accuracy of XGB Classifier on train set: 0.8624110609835477
# Accuracy of XGB Classifier on test set: 0.782027111949008
# XGB
#                precision    recall  f1-score   support
#
#        not 1       0.83      0.82      0.83      7017
#            1       0.70      0.72      0.71      4122
#
#     accuracy                           0.78     11139
#    macro avg       0.77      0.77      0.77     11139
# weighted avg       0.78      0.78      0.78     11139
